# %%
# https://www.asiabooks.com/home-top-chart.html?p=1

# %%
import requests
import re
import os
from bs4 import BeautifulSoup as bs

# %%
s.headers.update({'referer': my_referer})

# %%
res = requests.get("https://www.asiabooks.com/home-top-chart.html?p=1", headers={
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,th;q=0.7,zh-TW;q=0.6,ja;q=0.5',
    'Connection': 'keep-alive',
    'Cookie': 'frontend=smsiq20fhpros2jqthi6btmk47; external_no_cache=1; is_visited_customer=17',
    'Host': 'www.asiabooks.com',
    'Referer': 'https://www.asiabooks.com/',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'
})

# %%
bs_page = bs(res.content, features="lxml")

# %%
bs_page
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html lang="en" id="top" class="no-js ie6"> <![endif]--><!--[if IE 7 ]> <html lang="en" id="top" class="no-js ie7"> <![endif]--><!--[if IE 8 ]> <html lang="en" id="top" class="no-js ie8"> <![endif]--><!--[if IE 9 ]> <html lang="en" id="top" class="no-js ie9"> <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html class="no-js" id="top" lang="en"> <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Top chart | Asiabooks online bookstore in Thailand</title>
# <meta content="Top chart best price, easy, convenience from a great selection book at Asiabooks.com online bookstore in Thailand" name="description"/>
# ...

# %%
li_items = bs_page.findAll("li", {"class": "item"})

# %%
li_items
# Out:
# [<li class="item">
#  <div class="productlabel-wrap product-image">
#  <div class="product-image-content">
#  <a href="https://www.asiabooks.com/mindset-changing-the-way-you-think-to-fulfil-your-potential-167026.html" title="MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL">
# ...

# %%
info_dict = {}

# %%
tmp = li_items[0].find("h2", {'class': 'product-name'}).text

# %%
count = 0
for li_item in li_items:
    book_name = li_item.find("h2", {'class': 'product-name'}).text.strip()
    book_author = li_item.find("div", {'class': 'product-author'}).text.strip()
    book_price = li_item.find("span", {'class': 'price'}).text.strip()
    book_img_url = li_item.find("img").get('src')
    book_detail_url = li_item.find("a").get('href')
    info_dict[count] = [book_name, book_author, book_price, book_img_url, book_detail_url]
    count+=1

# %%
# Out:
# ['MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL',
#  'By DWECK, CAROL',
#  '฿337.50',
#  'https://www.asiabooks.com/media/catalog/product/cache/1/small_image/162x/17f82f742ffe127f42dca9de82fb58b1/9/7/9781472139955_4.jpg',
#  'https://www.asiabooks.com/mindset-changing-the-way-you-think-to-fulfil-your-potential-167026.html']

# %%
res = requests.get("https://www.asiabooks.com/home-top-chart.html?p=2", headers={
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,th;q=0.7,zh-TW;q=0.6,ja;q=0.5',
    'Connection': 'keep-alive',
    'Cookie': 'frontend=smsiq20fhpros2jqthi6btmk47; external_no_cache=1; is_visited_customer=17',
    'Host': 'www.asiabooks.com',
    'Referer': 'https://www.asiabooks.com/',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'
})

# %%
bs_page = bs(res.content, features="lxml")

# %%
li_items
# Out:
# [<li class="item">
#  <div class="productlabel-wrap product-image">
#  <div class="product-image-content">
#  <a href="https://www.asiabooks.com/how-to-win-friends-and-influence-people-10129.html" title="HOW TO WIN FRIENDS AND INFLUENCE PEOPLE">
#  <div class="amlabel-1 amlabel-table2 top-left" onclick="window.location='https://www.asiabooks.com/how-to-win-friends-and-influence-people-10129.html'"> <div class="amlabel-txt2 top-right" style="width:26%; background: url(https://www.asiabooks.com/media/amlabel/21010label-sales.png) no-repeat 0 0; font-size: 14px;color: #ffffff;text-transform:uppercase;font-weight: bold;text-align: center;padding: 1px 0;line-height: 1.5; max-height: 43px; max-width: 100%;"><div class="amlabel-txt">20%</div></div></div> <img alt="HOW TO WIN FRIENDS AND INFLUENCE PEOPLE" src="https://www.asiabooks.com/media/catalog/product/cache/1/small_image/162x/17f82f742ffe127f42dca9de82fb58b1/9/7/9781439199190c_7.png"/>
#  </a>
#  </div>
#  </div>
# ...

# %%
info_list = []

# %%
for i in (range(1, 10)):
    res = requests.get("https://www.asiabooks.com/home-top-chart.html?p=" + str(i), headers={
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,th;q=0.7,zh-TW;q=0.6,ja;q=0.5',
        'Connection': 'keep-alive',
        'Cookie': 'frontend=smsiq20fhpros2jqthi6btmk47; external_no_cache=1; is_visited_customer=17',
        'Host': 'www.asiabooks.com',
        'Referer': 'https://www.asiabooks.com/',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-User': '?1',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'
    })
    bs_page = bs(res.content, features="lxml")
    li_items = bs_page.findAll("li", {"class": "item"})
    for li_item in li_items:
        book_name = li_item.find("h2", {'class': 'product-name'}).text.strip()
        book_author = li_item.find("div", {'class': 'product-author'}).text.strip()
        book_price = li_item.find("span", {'class': 'price'}).text.strip()
        book_img_url = li_item.find("img").get('src')
        book_detail_url = li_item.find("a").get('href')
        info_list.append([book_name, book_author, book_price, book_img_url, book_detail_url])

# %%
len(info_list)
# Out:
# 144

# %%
info_list
# Out:
# [['MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL',
#   'By DWECK, CAROL',
#   '฿337.50',
#   'https://www.asiabooks.com/media/catalog/product/cache/1/small_image/162x/17f82f742ffe127f42dca9de82fb58b1/9/7/9781472139955_4.jpg',
#   'https://www.asiabooks.com/mindset-changing-the-way-you-think-to-fulfil-your-potential-167026.html'],
#  ['SAPIENS: A BRIEF HISTORY OF HUMANKIND',
#   'By HARARI, YUVAL NOAH',
#   '฿318.75',
#   'https://www.asiabooks.com/media/catalog/product/cache/1/small_image/162x/17f82f742ffe127f42dca9de82fb58b1/9/7/9780099590088A_3.jpg',
#   'https://www.asiabooks.com/sapiens-a-brief-history-of-humankind-25211.html'],
#  ['HOMO DEUS: A BRIEF HISTORY OF TOMORROW',
#   'By HARARI, YUVAL NOAH',
#   '฿318.75',
#   'https://www.asiabooks.com/media/catalog/product/cache/1/small_image/162x/17f82f742ffe127f42dca9de82fb58b1/9/7/9781784703936_5.jpg',
#   'https://www.asiabooks.com/homo-deus-a-brief-history-of-tomorrow-168097.html'],
# ...

# %%
for info in info_list:
    res = requests.get(info[3], headers={
        'Accept': 'image/avif,image/webp,image/apng,image/*,*/*;q=0.8',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,th;q=0.7,zh-TW;q=0.6,ja;q=0.5',
        'Connection': 'keep-alive',
        'Cookie': 'frontend=smsiq20fhpros2jqthi6btmk47; external_no_cache=1; is_visited_customer=20',
        'Host': 'www.asiabooks.com',
        'Referer': 'https://www.asiabooks.com/home-top-chart.html?p=3',
        'Sec-Fetch-Dest': 'image',
        'Sec-Fetch-Mode': 'no-cors',
        'Sec-Fetch-Site': 'same-origin',
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'
    })
    name = info[0].replace("/ ", "")
    with open(f'sources/imgs/{name}.jpg', 'wb') as f:
        f.write(res.content)

# %%
s = "PANTONE (GP1601A) FORMULA GUIDE SOLID COATED / UNCOATED.jpg"

# %%
s.replace("/ ", "")
# Out:
# 'PANTONE (GP1601A) FORMULA GUIDE SOLID COATED UNCOATED.jpg'

# %%
for info in info_list:
    res = requests.get(info[4], headers={
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,th;q=0.7,zh-TW;q=0.6,ja;q=0.5',
        'Connection': 'keep-alive',
        'Cookie': 'frontend=smsiq20fhpros2jqthi6btmk47; external_no_cache=1; is_visited_customer=23',
        'Host': 'www.asiabooks.com',
        'Referer': 'https://www.asiabooks.com/home-top-chart.html?p=1',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-User': '?1',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'
    })
    div_desc = ""
    bs_page = bs(res.content, features="lxml")
    if bs_page.find("div", {"class": "std"}) != None:
        div_desc = bs_page.find("div", {"class": "std"}).text.strip()
    info[3] = div_desc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-145-4ddd71639066> in <module>
#      16     })
#      17     bs_page = bs(res.content, features="lxml")
# ---> 18     div_desc = bs_page.find("div", {"class": "std"}).text.strip()
#      19     info[3] = div_desc
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
res = requests.get(info_list[0][4], headers={
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,th;q=0.7,zh-TW;q=0.6,ja;q=0.5',
    'Connection': 'keep-alive',
    'Cookie': 'frontend=smsiq20fhpros2jqthi6btmk47; external_no_cache=1; is_visited_customer=23',
    'Host': 'www.asiabooks.com',
    'Referer': 'https://www.asiabooks.com/home-top-chart.html?p=1',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'
})
bs_page = bs(res.content, features="lxml")

# %%
bs_page
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html lang="en" id="top" class="no-js ie6"> <![endif]--><!--[if IE 7 ]> <html lang="en" id="top" class="no-js ie7"> <![endif]--><!--[if IE 8 ]> <html lang="en" id="top" class="no-js ie8"> <![endif]--><!--[if IE 9 ]> <html lang="en" id="top" class="no-js ie9"> <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html class="no-js" id="top" lang="en"> <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL:DWECK, CAROL | Asiabooks.com</title>
# <meta content="Buy MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL:9781472139955 by DWECK, CAROL Psychology English Books available at Asiabooks.com with special promotions." name="description"/>
# <meta content="MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL" name="keywords"/>
# <meta content="INDEX,FOLLOW" name="robots"/>
# ...

# %%
div_desc = bs_page.find("div", {"class": "std"})

# %%
div_desc.text
# Out:
# "\nDweck explains why it's not just our abilities and talent that bring us success-but whether we approach them with a fixed or growth mindset. She makes clear why praising intelligence and ability doesn't foster self-esteem and lead to accomplishment, but may actually jeopardize success. With the right mindset, we can motivate our kids and help them to raise their grades, as well as reach our own goals-personal and professional. Dweck reveals what all great parents, teachers, CEOs, and athletes already know: how a simple idea about the brain can create a love of learning and a resilience that is the basis of great accomplishment in every area. "

# %%
info_list[3] = ['PRINCIPLES: LIFE AND WORK',
  'By DALIO, RAY',
  '฿746.25',
  'https://www.asiabooks.com/media/catalog/product/cache/1/small_image/162x/17f82f742ffe127f42dca9de82fb58b1/9/7/9781501124020_3.jpg',
  'https://www.asiabooks.com/principles-life-and-work-174598.html']

# %%
info_list[93]
# Out:
# ['PEPPA PIG: PRACTISE WIH PEPPA: WIPE-CLEAN NUMBERS',
#  '',
#  '฿108',
#  'https://www.asiabooks.com/media/catalog/product/cache/1/small_image/162x/17f82f742ffe127f42dca9de82fb58b1/9/7/9780723292111A_1.png',
#  'https://www.asiabooks.com/peppa-pig-practise-wih-peppa-wipe-clean-numbers-28639.html']

# %%
for i in range(93, len(info_list)-1):
    info = info_list[i]
    res = requests.get(info[4], headers={
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,th;q=0.7,zh-TW;q=0.6,ja;q=0.5',
        'Connection': 'keep-alive',
        'Cookie': 'frontend=smsiq20fhpros2jqthi6btmk47; external_no_cache=1; is_visited_customer=23',
        'Host': 'www.asiabooks.com',
        'Referer': 'https://www.asiabooks.com/home-top-chart.html?p=1',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-User': '?1',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'
    })
    div_desc = ""
    bs_page = bs(res.content, features="lxml")
    if bs_page.find("div", {"class": "std"}) != None:
        div_desc = bs_page.find("div", {"class": "std"}).text.strip()
    info[3] = div_desc

# %%
info_list
# Out:
# [['MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL',
#   'By DWECK, CAROL',
#   337.5,
#   "Dweck explains why it's not just our abilities and talent that bring us success-but whether we approach them with a fixed or growth mindset. She makes clear why praising intelligence and ability doesn't foster self-esteem and lead to accomplishment, but may actually jeopardize success. With the right mindset, we can motivate our kids and help them to raise their grades, as well as reach our own goals-personal and professional. Dweck reveals what all great parents, teachers, CEOs, and athletes already know: how a simple idea about the brain can create a love of learning and a resilience that is the basis of great accomplishment in every area.",
#   'MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL.jpg',
#   489,
#   62,
#   3],
#  ['SAPIENS: A BRIEF HISTORY OF HUMANKIND',
#   'By HARARI, YUVAL NOAH',
#   318.75,
# ...

# %%
for info in info_list:
    info[2] = info[2].replace("฿", "")

# %%
info_list[1]
# Out:
# ['SAPIENS: A BRIEF HISTORY OF HUMANKIND',
#  'By HARARI, YUVAL NOAH',
#  '318.75',
#  'Starting from this provocative idea, Sapiens goes on to retell the history of our species from a completely fresh perspective. It explains that money is the most pluralistic system of mutual trust ever devised; that capitalism is the most successful religion ever invented; that the treatment of animals in modern agriculture is probably the worst crime in history; and that even though we are far more powerful than our ancient ancestors, we aren’t much happier. By combining profound insights with a remarkably vivid language, Sapiens has already acquired almost cultic status among diverse audiences, captivating teenagers as well as university professors, animal rights activists alongside government ministers. It is currently being translated into close to thirty languages.',
#  'SAPIENS: A BRIEF HISTORY OF HUMANKIND.jpg']

# %%
import random

# %%
for info in info_list:
    info.append(random.randint(0,500))
    info.append(random.randint(0,500))
    info.append(random.randint(1,10))

# %%
info_list[2]
# Out:
# ['HOMO DEUS: A BRIEF HISTORY OF TOMORROW',
#  'By HARARI, YUVAL NOAH',
#  '318.75',
#  'Sapiens showed us where we came from. Homo Deus shows us where we\'re going. War is obsolete. You are more likely to commit suicide than be killed in conflict. Famine is disappearing. You are at more risk of obesity than starvation. Death is just a technical problem. Equality is out - but immortality is in. What does our future hold? Yuval Noah Harari, author of the bestselling phenomenon Sapiens envisions a not-too-distant world in which we face a new set of challenges. Homo Deus explores the projects, dreams and nightmares that will shape the twenty-first century - from overcoming death to creating artificial life. It asks the fundamental questions: Where do we go from here? And how will we protect this fragile world from our own destructive powers? "Homo Deus will shock you. It will entertain you. Above all, it will make you think in ways you had not thought before".',
# ...

# %%
for info in info_list:
    if type(info[2]) == str:
        info[2] = info[2].replace(",", "")
    info[2] = float(info[2])

# %%
for info in info_list[0]:
    print(type(info))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
import pymysql

# %%
# 打开数据库连接
db = pymysql.connect("localhost","root","00000000","book_store")

# %%
# 使用 cursor() 方法创建一个游标对象 cursor
cursor = db.cursor()

# %%
# SQL 插入语句
sql = "INSERT INTO book_info(name, author, price, description, big_cover, sales, stock, fk_category_id) VALUES (%s, %s, %f, $s, %s, %i, %i, %i)"

# %%
try:
   # 执行sql语句
   cursor.executemany(sql, info_list)
   # 提交到数据库执行
   db.commit()
except Exception as ex:
    print(ex)
except:
   # 如果发生错误则回滚
   db.rollback()
# Out:
# must be real number, not str

# %%
# 关闭数据库连接
db.close()

# %%
info_list[0]
# Out:
# ['MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL',
#  'By DWECK, CAROL',
#  337.5,
#  "Dweck explains why it's not just our abilities and talent that bring us success-but whether we approach them with a fixed or growth mindset. She makes clear why praising intelligence and ability doesn't foster self-esteem and lead to accomplishment, but may actually jeopardize success. With the right mindset, we can motivate our kids and help them to raise their grades, as well as reach our own goals-personal and professional. Dweck reveals what all great parents, teachers, CEOs, and athletes already know: how a simple idea about the brain can create a love of learning and a resilience that is the basis of great accomplishment in every area.",
#  'MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL.jpg',
#  489,
#  62,
#  3]

# %%
sql = "INSERT INTO book_info(name, author, price, description, big_cover, sales, stock, fk_category_id) VALUES (%s, %s, %s, $s, %s, %s, %s, %s)"

# %%
par = ('MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL', 'By DWECK, CAROL', "337.5", "Dweck explains why it's not just our abilities and talent that bring us success-but whether we approach them with a fixed or growth mindset. She makes clear why praising intelligence and ability doesn't foster self-esteem and lead to accomplishment, but may actually jeopardize success. With the right mindset, we can motivate our kids and help them to raise their grades, as well as reach our own goals-personal and professional. Dweck reveals what all great parents, teachers, CEOs, and athletes already know: how a simple idea about the brain can create a love of learning and a resilience that is the basis of great accomplishment in every area.", 'MINDSET: CHANGING THE WAY YOU THINK TO FULFIL YOUR POTENTIAL.jpg', "489", "62", "3")

# %%
par = (1,1,1,1,1,1,1,1)

# %%
type(par[0])
# Out:
# int

# %%
# 执行sql语句
cursor.execute(sql, par)
# 执行sql语句
db.commit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-279-fcf9a82e6d59> in <module>
#       1 # 执行sql语句
# ----> 2 cursor.execute(sql, par)
#       3 # 执行sql语句
#       4 db.commit()
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     166             pass
#     167
# --> 168         query = self.mogrify(query, args)
#     169
#     170         result = self._query(query)
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in mogrify(self, query, args)
#     145
#     146         if args is not None:
# --> 147             query = query % self._escape_args(args, conn)
#     148
#     149         return query
#
# TypeError: not all arguments converted during string formatting

# %%
# 关闭数据库连接
db.close()
